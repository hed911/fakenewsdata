# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, plot_confusion_matrix, plot_roc_curve

df = pd.read_csv("https://raw.githubusercontent.com/hed911/fakenewsdata/main/dataset.csv", sep=';')

# %%
df.head(10)
# Out:
#                      NAME          CITY    ID NUMBER GENDER  SOCIAL STATUS  \
# 0      Amb. Alfredo Rohan     Cartagena  057-35-3652      F              5
# 1              Elias Lowe     Cartagena  168-61-7060      M              4
# 2     Chassidy Rempel CPA   Santa Marta  142-51-3980      M              4
# 3           Palmer Beatty     Cartagena  812-16-5913      M              5
# 4         Wallace Kerluke   Santa Marta  578-66-8743      M              1
# 5           Vince Weimann  Barranquilla  374-24-7817      F              2
# 6  Charisse Abernathy Sr.  Barranquilla  539-52-7937      M              5
# 7              Carly Hand   Santa Marta  281-78-1579      F              1
# 8            James Bednar     Cartagena  015-39-8574      M              4
# 9           Zella Mills I     Cartagena  739-38-9857      M              1
#
#    AGE                     EDUCATION LEVEL  \
# 0   53                             Tecnico
# 1   52                             Tecnico
# ...

# %%
bins = [14, 24, 36, 46, 60]
df[df['FAKE NEWS SHARED THIS MONTH'] >= 4]['AGE'] .value_counts(bins=bins, sort=False)
# ESTA RARO, DEVISAR PORQUE HAY UN 0
# Out:
# (13.999, 24.0]    599
# (24.0, 36.0]        0
# (36.0, 46.0]       52
# (46.0, 60.0]      698
# Name: AGE, dtype: int64
